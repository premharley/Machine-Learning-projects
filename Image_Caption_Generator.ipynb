# %%
import google.generativeai as genai

# %%
genai.configure(api_key="AIzaSyB2WyTNxdK8exkLIqCWrocoBw3kE-PKUCU")

# %%
from PIL import Image
import matplotlib.pyplot as plt
img=Image.open(r"C:\Users\premc\Downloads\samsung-memory--jXG8UoBJLI-unsplash.jpg")
plt.imshow(img)

# %%
model =genai.GenerativeModel(model_name='gemini-1.5-flash-002')

prompt="Describe the picture clearly"
response=model.generate_content([img,prompt])

print(response.text)
# Out:
# Here's a description of the image:
#
# High-angle, close-up view of a person's hands typing on a silver laptop computer.
#
#
# Here's a breakdown of the scene:
#
# * **The Laptop:** A silver MacBook-style laptop is open, displaying a photo editing program on the screen. The screen shows a timeline, indicating video or photo editing in progress. The keyboard is dark and the trackpad is clean.
#
# * **The Person:** Only the person's forearms and hands are visible, actively typing. They appear to be a light-skinned male with some hair on their forearms.  The person is wearing a dark blue or black long-sleeved shirt.
#
# * **The Accessories:** Beside the laptop, on a light wood surface, are several items:
#     * A black Samsung portable SSD (solid-state drive) is connected to the laptop via a USB cable.
#     * Three Samsung PRO microSD cards, with capacities of 128GB, 256GB, and 512GB, are placed near the SSD.
#
# * **The Setting:** The background is a simple light-colored wood surface, suggesting a clean, organized workspace.
#
#
# The overall impression is one of a professional or enthusiast working on photo or video editing, using high-quality storage devices to manage their files.
